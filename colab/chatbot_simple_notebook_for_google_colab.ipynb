# %% [markdown]
# <a href="https://colab.research.google.com/github/cmanderskronquist/getting_started_with_ai/blob/main/colab/chatbot_simple_notebook_for_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This uses python files from Github to run them in Colab
#
# WARNING
# Saving this from Colab to Github will overwrite the file no questions asked. No merge option. It is highly recommended to use separate branches and do manual merges if that works.

# %% [markdown]
# Run this to clone the repo

# %%
![ ! -d "getting_started_with_ai" ] && git clone https://github.com/cmanderskronquist/getting_started_with_ai/
# Out:
# Cloning into 'getting_started_with_ai'...
# remote: Enumerating objects: 161, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 161 (delta 67), reused 99 (delta 36), pack-reused 0 (from 0)
# Receiving objects: 100% (161/161), 179.77 KiB | 3.33 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %% [markdown]
# Run this to refresh the clone.

# %%
# !cd getting_started_with_ai/ && git pull
# Out:
# Already up to date.

# %% [markdown]
# And finally, run the chatbot python script.

# %%
# !pip install faiss-cpu

# %%
run getting_started_with_ai/chatbot_from_documents/chatbot_from_docs_simple.py
# Out:
# Dokumentets längd: 1610 tecken
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

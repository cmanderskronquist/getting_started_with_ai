# %% [markdown]
# <a href="https://colab.research.google.com/github/cmanderskronquist/getting_started_with_ai/blob/svinline/colab/inline_gTTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a test of pulling from github to Colab
#
# WARNING
# Saving this from Colab to Github will overwrite the file no questions asked. No merge option.

# %% [markdown]
# # Install needed dependencies

# %% [markdown]
# Run this to clone the repo

# %%
![ ! -d "getting_started_with_ai" ] && git clone https://github.com/cmanderskronquist/getting_started_with_ai/
# Out:
# Cloning into 'getting_started_with_ai'...
# remote: Enumerating objects: 218, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 218 (delta 8), reused 1 (delta 0), pack-reused 202 (from 1)
# Receiving objects: 100% (218/218), 376.19 KiB | 3.69 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %% [markdown]
# Run this to refresh the clone.

# %%
# !cd getting_started_with_ai/ && git pull
# Out:
# Already up to date.

# %% [markdown]
# Look for requirements.txt in the project.
#
# WARNING this looks for as specific file, not generic.

# %%
# !pip install -r getting_started_with_ai/colab/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 46.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 87.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 22.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 64.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# And finally, run main.py

# %%
cat /content/getting_started_with_ai/colab/main.py
# Out:
# #!/bin/python3
#
# from helloworld import hello
# from gtts import gTTS
# from IPython.display import Audio, display, HTML
#
# tts = gTTS('The quick brown fox jumps over the lazy dog.', tld='co.uk')
# tts.save('uk.mp3')
# tts = gTTS('The quick brown fox jumps over the lazy dog.', tld='com')
# tts.save('us.mp3')
# tts = gTTS('The quick brown fox jumps over the lazy dog.', tld='com.au')
# tts.save('au.mp3')
# tts = gTTS('The quick brown fox jumps over the lazy dog.', tld='co.in')
# tts.save('in.mp3')
# tts = gTTS('The quick brown fox jumps over the lazy dog.', lang='sv') #tld='se')
# tts.save('se.mp3')
#
# display(HTML('<p>SE:</p>'))
# display(Audio('se.mp3', autoplay=True))
# display(HTML('<p>UK:</p>'))
# display(Audio('uk.mp3', autoplay=False))
# display(HTML('<p>US:</p>'))
# display(Audio('us.mp3', autoplay=False))
# display(HTML('<p>AU:</p>'))
# display(Audio('au.mp3', autoplay=False))
# display(HTML('<p>IN:</p>'))
# display(Audio('in.mp3', autoplay=False))

# %% [markdown]
# # INLINE CODE copied from above and edited

# %%
from gtts import gTTS
from IPython.display import Audio, display, HTML

tts = gTTS('The quick brown fox jumps over the lazy dog.', tld='co.uk')
tts.save('uk.mp3')
tts = gTTS('The quick brown fox jumps over the lazy dog.', tld='com')
tts.save('us.mp3')
tts = gTTS('The quick brown fox jumps over the lazy dog.', tld='com.au')
tts.save('au.mp3')
tts = gTTS('The quick brown fox jumps over the lazy dog.', tld='co.in')
tts.save('in.mp3')
tts = gTTS('The quick brown fox jumps over the lazy dog.', lang='sv') #tld='se')
tts.save('se.mp3')

display(HTML('<p>SE:</p>'))
display(Audio('se.mp3', autoplay=True))
display(HTML('<p>UK:</p>'))
display(Audio('uk.mp3', autoplay=False))
display(HTML('<p>US:</p>'))
display(Audio('us.mp3', autoplay=False))
display(HTML('<p>AU:</p>'))
display(Audio('au.mp3', autoplay=False))
display(HTML('<p>IN:</p>'))
display(Audio('in.mp3', autoplay=False))
# Out:
# <p>SE:</p>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# <p>UK:</p>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# <p>US:</p>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# <p>AU:</p>
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ...

# %% [markdown]
# # INLINE CODE copied from above and edited

# %%
# !pip install ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Playing around with gTTS - currently speaking latin

# %%
from gtts import gTTS
#import os
#import ipywidgets as widgets
from IPython.display import Audio, display, HTML#, FileLink

#def save_file_button(file_path, button_text='Download File'):
"""
    """ """
    Displays a button that triggers a file download when clicked.

    Args:
    file_path (str): Path to the file to be downloaded.
    button_text (str, optional): Text displayed on the button. Defaults to 'Download File'.
    """ """
    file_link = FileLink(file_path)  # Creates a FileLink object for the given file
    file_link.target = '_blank'  # Opens the downloaded file in a new tab

    button = widgets.Button(description=button_text)  # Create a button widget
    button.on_click(lambda b: file_link._repr_html_())  # Display the file for download on click

    display(button, file_link)  # Show both the button and FileLink object
"""
myTLD = ''
#myTLD = 'co.uk'
#myLang = 'en-uk'
#myTLD = 'com'
#myLang = 'en-us'
#myTLD = 'com.au'
#myLang = 'en-au'
#myTLD = 'co.in'
#myLang = 'en-in'
#myLang = 'sv' myTLD = 'se'
myLang = 'la'

mySpokenTextFile='spoken.mp3'

# myText = 'The quick brown fox jumps over the lazy dog.'
myText = 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.'

#tts = gTTS(myText, tld=myTLD)
tts = gTTS(myText, lang=myLang)
tts.save(mySpokenTextFile)
#myPath = os.path.join(os.getcwd(), mySpokenTextFile)

display(HTML('<p>' + myTLD + myLang +'</p>'))
display(Audio(mySpokenTextFile, autoplay=True))
#save_file_button(myPath)  # Replace 'path/to/your/file.txt' with the actual file path.
# Out:
# <p>la</p>
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Now, something different

# %%
from TTS.api import TTS
from IPython.display import Audio, display, HTML

myLang = 'en-uk'
myTLD = 'co.uk'
myText = 'The quick brown fox jumps over the lazy dog.'
myFile = 'tts.wav'
myTTS = TTS(model_name="tts_models/en/ljspeech/tacotron2-DDC", progress_bar=False)
#tts = tts.TTS(myText, lang=myLang, tld=myTLD)
myTTS.tts_to_file(text=myText, file_path=myFile)
#tts.save(myFile)

display(HTML('<p>' + myTLD + myLang +'</p>'))
display(Audio(myFile, autoplay=True))
#
# Out:
#  > tts_models/en/ljspeech/tacotron2-DDC is already downloaded.
#  > vocoder_models/en/ljspeech/hifigan_v2 is already downloaded.
#  > Using model: Tacotron2
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
# ...

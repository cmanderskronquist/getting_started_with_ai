# %% [markdown]
# <a href="https://colab.research.google.com/github/cmanderskronquist/getting_started_with_ai/blob/main/chatterbox_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎙️ Chatterbox TTS & Voice Conversion - Google Colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bhootnaat22/chatterbox-colab/blob/master/chatterbox_colab.ipynb)
#
# Welcome to Chatterbox - Resemble AI's open-source TTS and Voice Conversion model!
#
# This notebook provides:
# - 🎯 **Text-to-Speech (TTS)** with emotion control
# - 🔄 **Voice Conversion** to change voice characteristics
# - 🌐 **Live Gradio Interface** accessible via public URL
# - ⚡ **GPU acceleration** when available
#
# ## Features:
# - Zero-shot TTS with custom voice cloning
# - Emotion/exaggeration control
# - Voice conversion between different speakers
# - Built-in watermarking for responsible AI
# - Easy-to-use web interface

# %% [markdown]
# ## 🚀 Setup and Installation
#
# First, let's install all the required dependencies:

# %%
# Install system dependencies
#!apt-get update
#!apt-get install -y -qq ffmpeg
# !apt-get install python3.11 python3.11-venv
# !apt-get install -y -qq build-essential python3.11-dev pkg-config cmake ffmpeg \
                     libffi-dev libssl-dev libsndfile1
# !apt-get install -y -qq cargo rustc
# !rm -r .chatterbox
# !python3.11 -m venv .chatterbox
# !source .chatterbox/bin/activate
# !/content/.chatterbox/bin/python --version
# !/content/.chatterbox/bin/python -m pip install -q --upgrade pip setuptools wheel
# Install Python dependencies
# !/content/.chatterbox/bin/python -m pip install numpy
# !/content/.chatterbox/bin/python -m pip install chatterbox-tts gradio

#print("✅ Installation complete!")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.11 is already the newest version (3.11.13-1+jammy1).
# python3.11-venv is already the newest version (3.11.13-1+jammy1).
# The following packages were automatically installed and are no longer required:
#   libbz2-dev libpkgconf3 libreadline-dev
# Use 'apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# Python 3.11.13
# Collecting numpy
#   Using cached numpy-2.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Downloading numpy-2.3.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 122.1 MB/s  0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.3.3
# Collecting chatterbox-tts
#   Using cached chatterbox_tts-0.1.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting gradio
#   Using cached gradio-5.49.1-py3-none-any.whl.metadata (16 kB)
# Collecting numpy<1.26.0,>=1.24.0 (from chatterbox-tts)
#   Using cached numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting librosa==0.11.0 (from chatterbox-tts)
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting s3tokenizer (from chatterbox-tts)
#   Using cached s3tokenizer-0.2.0.tar.gz (225 kB)
#   Preparing metadata (setup.py) ... done
# Collecting torch==2.6.0 (from chatterbox-tts)
#   Using cached torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchaudio==2.6.0 (from chatterbox-tts)
#   Using cached torchaudio-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting transformers==4.46.3 (from chatterbox-tts)
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# Collecting diffusers==0.29.0 (from chatterbox-tts)
#   Using cached diffusers-0.29.0-py3-none-any.whl.metadata (19 kB)
# Collecting resemble-perth==1.0.1 (from chatterbox-tts)
#   Using cached resemble_perth-1.0.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting conformer==0.3.2 (from chatterbox-tts)
#   Using cached conformer-0.3.2-py3-none-any.whl.metadata (631 bytes)
# Collecting safetensors==0.5.3 (from chatterbox-tts)
#   Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting pkuseg==0.0.25 (from chatterbox-tts)
#   Using cached pkuseg-0.0.25.tar.gz (48.8 MB)
#   Preparing metadata (setup.py) ... done
# Collecting pykakasi==2.3.0 (from chatterbox-tts)
#   Downloading pykakasi-2.3.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting gradio
#   Downloading gradio-5.44.1-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting anyio<5.0,>=3.0 (from gradio)
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.118.2-py3-none-any.whl.metadata (28 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.6.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.12.1 (from gradio)
#   Downloading gradio_client-1.12.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting httpx<1.0,>=0.24.1 (from gradio)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub<1.0,>=0.33.5 (from gradio)
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting jinja2<4.0 (from gradio)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe<4.0,>=2.0 (from gradio)
#   Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting packaging (from gradio)
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pandas<3.0,>=1.0 (from gradio)
#   Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting pillow<12.0,>=8.0 (from gradio)
#   Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting pydantic<2.12,>=2.0 (from gradio)
#   Downloading pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting pyyaml<7.0,>=5.0 (from gradio)
#   Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting ruff>=0.9.3 (from gradio)
#   Downloading ruff-0.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.48.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.19.2-py3-none-any.whl.metadata (16 kB)
# Collecting typing-extensions~=4.0 (from gradio)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.37.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting einops>=0.6.1 (from conformer==0.3.2->chatterbox-tts)
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting importlib-metadata (from diffusers==0.29.0->chatterbox-tts)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting filelock (from diffusers==0.29.0->chatterbox-tts)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from diffusers==0.29.0->chatterbox-tts)
#   Downloading regex-2025.9.18-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting requests (from diffusers==0.29.0->chatterbox-tts)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting fsspec (from gradio-client==1.12.1->gradio)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting websockets<16.0,>=10.0 (from gradio-client==1.12.1->gradio)
#   Downloading websockets-15.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting audioread>=2.1.9 (from librosa==0.11.0->chatterbox-tts)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numba>=0.51.0 (from librosa==0.11.0->chatterbox-tts)
#   Downloading numba-0.62.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting scipy>=1.6.0 (from librosa==0.11.0->chatterbox-tts)
#   Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting scikit-learn>=1.1.0 (from librosa==0.11.0->chatterbox-tts)
#   Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting joblib>=1.0 (from librosa==0.11.0->chatterbox-tts)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting decorator>=4.3.0 (from librosa==0.11.0->chatterbox-tts)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting soundfile>=0.12.1 (from librosa==0.11.0->chatterbox-tts)
#   Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa==0.11.0->chatterbox-tts)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa==0.11.0->chatterbox-tts)
#   Downloading soxr-1.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Collecting lazy_loader>=0.1 (from librosa==0.11.0->chatterbox-tts)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa==0.11.0->chatterbox-tts)
#   Downloading msgpack-1.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting cython (from pkuseg==0.0.25->chatterbox-tts)
#   Using cached cython-3.1.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Collecting jaconv (from pykakasi==2.3.0->chatterbox-tts)
#   Downloading jaconv-0.4.0.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecated (from pykakasi==2.3.0->chatterbox-tts)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting networkx (from torch==2.6.0->chatterbox-tts)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0->chatterbox-tts)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch==2.6.0->chatterbox-tts)
#   Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting sympy==1.13.1 (from torch==2.6.0->chatterbox-tts)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch==2.6.0->chatterbox-tts)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.46.3->chatterbox-tts)
#   Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting tqdm>=4.27 (from transformers==4.46.3->chatterbox-tts)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting idna>=2.8 (from anyio<5.0,>=3.0->gradio)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting sniffio>=1.1 (from anyio<5.0,>=3.0->gradio)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting certifi (from httpx<1.0,>=0.24.1->gradio)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1.0,>=0.24.1->gradio)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.33.5->gradio)
#   Downloading hf_xet-1.1.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Collecting python-dateutil>=2.8.2 (from pandas<3.0,>=1.0->gradio)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas<3.0,>=1.0->gradio)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0,>=1.0->gradio)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<2.12,>=2.0->gradio)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.0->gradio)
#   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<2.12,>=2.0->gradio)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting click>=8.0.0 (from typer<1.0,>=0.12->gradio)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.51.0->librosa==0.11.0->chatterbox-tts)
#   Downloading llvmlite-0.45.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting platformdirs>=2.5.0 (from pooch>=1.1->librosa==0.11.0->chatterbox-tts)
#   Downloading platformdirs-4.5.0-py3-none-any.whl.metadata (12 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests->diffusers==0.29.0->chatterbox-tts)
#   Downloading charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (36 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->diffusers==0.29.0->chatterbox-tts)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.1.0->librosa==0.11.0->chatterbox-tts)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cffi>=1.0 (from soundfile>=0.12.1->librosa==0.11.0->chatterbox-tts)
#   Downloading cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=1.0->soundfile>=0.12.1->librosa==0.11.0->chatterbox-tts)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting wrapt<2,>=1.10 (from deprecated->pykakasi==2.3.0->chatterbox-tts)
#   Downloading wrapt-1.17.3-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Collecting zipp>=3.20 (from importlib-metadata->diffusers==0.29.0->chatterbox-tts)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting pre-commit (from s3tokenizer->chatterbox-tts)
#   Downloading pre_commit-4.3.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting onnx (from s3tokenizer->chatterbox-tts)
#   Downloading onnx-1.19.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.0 kB)
# Collecting protobuf>=4.25.1 (from onnx->s3tokenizer->chatterbox-tts)
#   Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting ml_dtypes (from onnx->s3tokenizer->chatterbox-tts)
#   Downloading ml_dtypes-0.5.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting cfgv>=2.0.0 (from pre-commit->s3tokenizer->chatterbox-tts)
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit->s3tokenizer->chatterbox-tts)
#   Downloading identify-2.6.15-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit->s3tokenizer->chatterbox-tts)
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit->s3tokenizer->chatterbox-tts)
#   Downloading virtualenv-20.34.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit->s3tokenizer->chatterbox-tts)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Downloading chatterbox_tts-0.1.4-py3-none-any.whl (100 kB)
# Downloading gradio-5.44.1-py3-none-any.whl (60.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 MB 70.9 MB/s  0:00:00
# Downloading conformer-0.3.2-py3-none-any.whl (4.3 kB)
# Downloading diffusers-0.29.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 82.3 MB/s  0:00:00
# Downloading gradio_client-1.12.1-py3-none-any.whl (324 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading pykakasi-2.3.0-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 90.7 MB/s  0:00:00
# Downloading resemble_perth-1.0.1-py3-none-any.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 69.8 MB/s  0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 29.8 MB/s  0:00:14
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 25.4 MB/s  0:00:10
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.6 MB/s  0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 108.6 MB/s  0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.6 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 17.2 MB/s  0:00:18
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 67.0 MB/s  0:00:03
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 55.5 MB/s  0:00:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 60.2 MB/s  0:00:02
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 59.1 MB/s  0:00:03
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 47.8 MB/s  0:00:03
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 48.9 MB/s  0:00:03
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.5 MB/s  0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 48.5 MB/s  0:00:00
# Downloading torchaudio-2.6.0-cp311-cp311-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 46.2 MB/s  0:00:00
# Downloading transformers-4.46.3-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 53.9 MB/s  0:00:00
# Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 41.0 MB/s  0:00:06
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
# Downloading fastapi-0.118.2-py3-none-any.whl (97 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading huggingface_hub-0.35.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 18.6 MB/s  0:00:00
# Downloading hf_xet-1.1.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 52.2 MB/s  0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 18.3 MB/s  0:00:00
# Downloading numpy-1.25.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 52.5 MB/s  0:00:00
# Downloading orjson-3.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (132 kB)
# Downloading pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 58.8 MB/s  0:00:00
# Downloading pillow-11.3.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 62.8 MB/s  0:00:00
# Downloading pydantic-2.11.10-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 45.2 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.6/806.6 kB 23.3 MB/s  0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.48.0-py3-none-any.whl (73 kB)
# Downloading tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 54.3 MB/s  0:00:00
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading typer-0.19.2-py3-none-any.whl (46 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading websockets-15.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading Brotli-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 59.4 MB/s  0:00:00
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (426 kB)
# Downloading numba-0.62.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 64.8 MB/s  0:00:00
# Downloading llvmlite-0.45.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 54.8 MB/s  0:00:01
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading platformdirs-4.5.0-py3-none-any.whl (18 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading regex-2025.9.18-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (798 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.0/799.0 kB 27.8 MB/s  0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (150 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 44.3 MB/s  0:00:00
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading ruff-0.14.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 83.2 MB/s  0:00:00
# Downloading scikit_learn-1.7.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 75.3 MB/s  0:00:00
# Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 35.3 MB/s  0:00:01
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.8 MB/s  0:00:00
# Downloading cffi-2.0.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (215 kB)
# Downloading soxr-1.0.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (242 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading uvicorn-0.37.0-py3-none-any.whl (67 kB)
# Using cached cython-3.1.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading wrapt-1.17.3-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (82 kB)
# Downloading ffmpy-0.6.2-py3-none-any.whl (5.5 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 47.9 MB/s  0:00:00
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading onnx-1.19.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 67.4 MB/s  0:00:00
# Downloading protobuf-6.32.1-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
# Downloading ml_dtypes-0.5.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 58.2 MB/s  0:00:00
# Downloading pre_commit-4.3.0-py2.py3-none-any.whl (220 kB)
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading identify-2.6.15-py2.py3-none-any.whl (99 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading virtualenv-20.34.0-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 58.2 MB/s  0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
# Building wheels for collected packages: pkuseg, jaconv, s3tokenizer
#   DEPRECATION: Building 'pkuseg' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pkuseg'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for pkuseg (setup.py) ... done
#   Created wheel for pkuseg: filename=pkuseg-0.0.25-cp311-cp311-linux_x86_64.whl size=50673637 sha256=7aefd10288ceca441d9b39f21bd8bd1ce978c075eddb7d33a0dbc19ac0c0a4d8
#   Stored in directory: /root/.cache/pip/wheels/6e/b9/d9/3cfceef165811a9dfc46c94ab798e429cf413de917aba799ca
#   DEPRECATION: Building 'jaconv' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'jaconv'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for jaconv (setup.py) ... done
#   Created wheel for jaconv: filename=jaconv-0.4.0-py3-none-any.whl size=18313 sha256=ab888aee18572b035a590f46970f2ed2d991ceb6f405a5d88b682954998cb337
#   Stored in directory: /root/.cache/pip/wheels/1c/63/71/95fb322fe9047ed7e61b007c47cbf03d23ecb77dd03665f151
#   DEPRECATION: Building 's3tokenizer' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 's3tokenizer'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for s3tokenizer (setup.py) ... done
#   Created wheel for s3tokenizer: filename=s3tokenizer-0.2.0-py3-none-any.whl size=221655 sha256=64849ae625ddb05145edd059638c58d61f4e5f5666b11f0c6d22594d15d093c5
#   Stored in directory: /root/.cache/pip/wheels/af/de/16/4967b3bfa69472030df5074d4b646ccae9630a6b3bc7000be0
# Successfully built pkuseg jaconv s3tokenizer
# Installing collected packages: triton, pytz, pydub, nvidia-cusparselt-cu12, mpmath, jaconv, distlib, brotli, zipp, wrapt, websockets, urllib3, tzdata, typing-extensions, tqdm, tomlkit, threadpoolctl, sympy, sniffio, six, shellingham, semantic-version, safetensors, ruff, resemble-perth, regex, pyyaml, python-multipart, pygments, pycparser, protobuf, platformdirs, pillow, packaging, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, nodeenv, networkx, msgpack, mdurl, markupsafe, llvmlite, joblib, idna, identify, hf-xet, h11, groovy, fsspec, filelock, ffmpy, einops, decorator, cython, click, charset_normalizer, cfgv, certifi, audioread, annotated-types, aiofiles, virtualenv, uvicorn, typing-inspection, soxr, scipy, requests, python-dateutil, pydantic-core, pkuseg, nvidia-cusparse-cu12, nvidia-cudnn-cu12, numba, ml_dtypes, markdown-it-py, lazy_loader, jinja2, importlib-metadata, httpcore, deprecated, cffi, anyio, starlette, soundfile, scikit-learn, rich, pykakasi, pydantic, pre-commit, pooch, pandas, onnx, nvidia-cusolver-cu12, huggingface-hub, httpx, typer, torch, tokenizers, safehttpx, librosa, gradio-client, fastapi, diffusers, transformers, torchaudio, gradio, conformer, s3tokenizer, chatterbox-tts
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118/118 [chatterbox-tts]
# Successfully installed aiofiles-24.1.0 annotated-types-0.7.0 anyio-4.11.0 audioread-3.0.1 brotli-1.1.0 certifi-2025.10.5 cffi-2.0.0 cfgv-3.4.0 charset_normalizer-3.4.3 chatterbox-tts-0.1.4 click-8.3.0 conformer-0.3.2 cython-3.1.4 decorator-5.2.1 deprecated-1.2.18 diffusers-0.29.0 distlib-0.4.0 einops-0.8.1 fastapi-0.118.2 ffmpy-0.6.2 filelock-3.20.0 fsspec-2025.9.0 gradio-5.44.1 gradio-client-1.12.1 groovy-0.1.2 h11-0.16.0 hf-xet-1.1.10 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-0.35.3 identify-2.6.15 idna-3.10 importlib-metadata-8.7.0 jaconv-0.4.0 jinja2-3.1.6 joblib-1.5.2 lazy_loader-0.4 librosa-0.11.0 llvmlite-0.45.1 markdown-it-py-4.0.0 markupsafe-3.0.3 mdurl-0.1.2 ml_dtypes-0.5.3 mpmath-1.3.0 msgpack-1.1.2 networkx-3.5 nodeenv-1.9.1 numba-0.62.1 numpy-1.25.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 onnx-1.19.0 orjson-3.11.3 packaging-25.0 pandas-2.3.3 pillow-11.3.0 pkuseg-0.0.25 platformdirs-4.5.0 pooch-1.8.2 pre-commit-4.3.0 protobuf-6.32.1 pycparser-2.23 pydantic-2.11.10 pydantic-core-2.33.2 pydub-0.25.1 pygments-2.19.2 pykakasi-2.3.0 python-dateutil-2.9.0.post0 python-multipart-0.0.20 pytz-2025.2 pyyaml-6.0.3 regex-2025.9.18 requests-2.32.5 resemble-perth-1.0.1 rich-14.2.0 ruff-0.14.0 s3tokenizer-0.2.0 safehttpx-0.1.6 safetensors-0.5.3 scikit-learn-1.7.2 scipy-1.16.2 semantic-version-2.10.0 shellingham-1.5.4 six-1.17.0 sniffio-1.3.1 soundfile-0.13.1 soxr-1.0.0 starlette-0.48.0 sympy-1.13.1 threadpoolctl-3.6.0 tokenizers-0.20.3 tomlkit-0.13.3 torch-2.6.0 torchaudio-2.6.0 tqdm-4.67.1 transformers-4.46.3 triton-3.2.0 typer-0.19.2 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2025.2 urllib3-2.5.0 uvicorn-0.37.0 virtualenv-20.34.0 websockets-15.0.1 wrapt-1.17.3 zipp-3.23.0

# %% [markdown]
# ## 🔧 Device Configuration
#
# Let's check what hardware we have available:

# %%
import torch
import platform

# Check available devices
if torch.cuda.is_available():
    device = "cuda"
    gpu_name = torch.cuda.get_device_name(0)
    gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
    print(f"🚀 GPU Available: {gpu_name}")
    print(f"💾 GPU Memory: {gpu_memory:.1f} GB")
elif torch.backends.mps.is_available():
    device = "mps"
    print("🍎 Apple MPS Available")
else:
    device = "cpu"
    print("💻 Using CPU")

print(f"🎯 Selected device: {device}")
print(f"🐍 Python version: {platform.python_version()}")
print(f"🔥 PyTorch version: {torch.__version__}")
# Out:
# 🚀 GPU Available: Tesla T4
# 💾 GPU Memory: 14.7 GB
# 🎯 Selected device: cuda
# 🐍 Python version: 3.12.11
# 🔥 PyTorch version: 2.8.0+cu126

# %% [markdown]
# ## 📱 Download Gradio App
#
# Let's download the optimized Gradio application:

# %%
# Download the Colab-optimized Gradio app
# !wget -q https://raw.githubusercontent.com/bhootnaat22/chatterbox-colab/master/colab_gradio_app.py

print("✅ Gradio app downloaded!")
# Out:
# ✅ Gradio app downloaded!

# %% [markdown]
# ## 🌐 Launch Gradio Interface
#
# Now let's launch the interactive web interface!
#
# **Note:** The first run will download the model weights (~2GB), which may take a few minutes.

# %%
# Launch the Gradio app
# !/content/.chatterbox/bin/python colab_gradio_app.py
# Out:
# /content/.chatterbox/lib/python3.11/site-packages/perth/perth_net/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename
# 🎯 Using device: cuda
# ℹ️  Note: CUDA warnings above are normal in Colab and can be ignored
# 🚀 Starting Chatterbox Gradio App...
# 📱 This may take a few minutes on first run (downloading models)
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://2c72c390fc9bf77d46.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)

# %% [markdown]
# ## 📖 Usage Instructions
#
# ### Text-to-Speech (TTS)
# 1. **Enter text** you want to synthesize (max 300 characters)
# 2. **Upload reference audio** (optional) to clone a specific voice
# 3. **Adjust parameters:**
#    - **Exaggeration**: Controls emotion intensity (0.5 = neutral)
#    - **CFG/Pace**: Controls generation pace and quality
#    - **Temperature**: Controls randomness in generation
# 4. **Click Generate** to create speech
#
# ### Voice Conversion (VC)
# 1. **Upload source audio** you want to convert
# 2. **Upload target voice** (optional) to specify the target voice
# 3. **Click Submit** to convert the voice
#
# ### Tips for Best Results
# - Use clear, high-quality reference audio (3-10 seconds)
# - For dramatic speech: lower CFG (~0.3) + higher exaggeration (~0.7)
# - For natural speech: keep default settings (exaggeration=0.5, CFG=0.5)
# - Reference audio should match the desired speaking style

# %% [markdown]
# ## 🎵 Quick Test Examples
#
# Want to test the models quickly? Run these examples:

# %%
# Quick TTS test
import torchaudio as ta
from chatterbox.tts import ChatterboxTTS

print("Loading TTS model...")
model = ChatterboxTTS.from_pretrained(device=device)

text = "Hello! This is Chatterbox TTS running in Google Colab. How does it sound?"
print(f"Generating speech for: '{text}'")

wav = model.generate(text)
ta.save("test_output.wav", wav, model.sr)

print("✅ TTS test complete! Audio saved as 'test_output.wav'")

# Play the audio in Colab
from IPython.display import Audio, display
display(Audio("test_output.wav"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-530409161.py in <cell line: 0>()
#       1 # Quick TTS test
#       2 import torchaudio as ta
# ----> 3 from chatterbox.tts import ChatterboxTTS
#       4
#       5 print("Loading TTS model...")
#
# ModuleNotFoundError: No module named 'chatterbox'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 🔧 Troubleshooting
#
# ### Common Issues:
#
# 1. **Out of Memory Error**:
#    - Restart runtime: `Runtime → Restart Runtime`
#    - Use shorter text inputs
#    - Try CPU mode if GPU memory is insufficient
#
# 2. **Model Download Issues**:
#    - Check internet connection
#    - Restart and try again
#    - Models are ~2GB total
#
# 3. **Audio Quality Issues**:
#    - Use high-quality reference audio (16kHz+)
#    - Keep reference audio 3-10 seconds long
#    - Adjust exaggeration and CFG parameters
#
# 4. **Gradio Interface Not Loading**:
#    - Wait for model initialization to complete
#    - Check the public URL in the output
#    - Try refreshing the browser
#
# ### Performance Tips:
# - GPU: ~10-30 seconds per generation
# - CPU: ~1-3 minutes per generation
# - Shorter texts generate faster
# - First generation takes longer (model loading)

# %% [markdown]
# ## 🎉 Enjoy Chatterbox!
#
# You now have a fully functional TTS and Voice Conversion system running in Google Colab!
#
# ### Links:
# - 🏠 [Chatterbox GitHub](https://github.com/resemble-ai/chatterbox)
# - 🤗 [Hugging Face Space](https://huggingface.co/spaces/ResembleAI/Chatterbox)
# - 🎵 [Demo Samples](https://resemble-ai.github.io/chatterbox_demopage/)
# - 💬 [Discord Community](https://discord.gg/rJq9cRJBJ6)
#
# ### Made with ❤️ by [Resemble AI](https://resemble.ai)
#
# ---
# *Remember to use this technology responsibly and ethically!*
